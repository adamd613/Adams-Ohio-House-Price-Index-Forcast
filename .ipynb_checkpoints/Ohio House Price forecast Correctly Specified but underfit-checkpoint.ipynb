# %%
import numpy as np
from fredapi import Fred
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm
import matplotlib.pyplot as plt
from datetime import datetime

# Set your FRED API key
fred = Fred(api_key='Enter Your API Key Here')

# %%
# Fetch data for Ohio HPI, USA HPI, Ohio Housing Permits, USA Housing Permits, Ohio Population, USA Population, 30-Year Mortgage Rate, and US Working-Age Population (25-54)
oh_hpi = fred.get_series("OHSTHPI")
us_hpi = fred.get_series("USSTHPI")
oh_permits = fred.get_series("OHBPPRIV")
us_permits = fred.get_series("PERMITNSA")
oh_population = fred.get_series("OHPOP")
us_population = fred.get_series("POPTHM")
mortgage_rate_30yr = fred.get_series("MORTGAGE30US")
us_population_25_54 = fred.get_series("LNU00000060")
us_population_65 = fred.get_series("SPPOP65UPTOZSUSA")
clevel_pop = fred.get_series("CVLPOP")
cle_hpi = fred.get_series("ATNHPIUS39035A")
us_population_20_24 = fred.get_series("LNU00000036")
cle_new_listings = fred.get_series("NEWLISCOU39035")
us_new_listings = fred.get_series("MSACSR")
oh_new_listings = fred.get_series("MSACSR")
cle_hotness = fred.get_series("SUSCCOUNTY39035")
debt_to_Income = fred.get_series("TDSP")
mortgage_to_Income = fred.get_series("MDSP")
Delinquency_to_Income = fred.get_series("DRSFRMACBS")
Unemployment = fred.get_series("UNRATE")
CleUnemployment = fred.get_series("OHCUYA5URN")
CleSalaries = fred.get_series("SMU39174600500000003")
Salaries = fred.get_series("BA06RC1A027NBEA")
CPI = fred.get_series("CPIAUCSL")
CCDelinq = fred.get_series("DRCCLACBS")
HousingInventory = fred.get_series("EYRVACUSQ176N")
SP500 = fred.get_series("SP500")
RGDP = fred.get_series("GDPC1")

# %%
# Combine all series into a single DataFrame, comment out variables you do not need.
hpi_df = pd.DataFrame({
    "Ohio HPI": oh_hpi,
    "USA HPI": us_hpi,
    #"Ohio Housing Permits": oh_permits,
    #"USA Housing Permits": us_permits,
    #"Ohio Population": oh_population,
    #"USA Population": us_population,
    #"Cleveland Population" : clevel_pop,
    #"US Population (Over 65)": us_population_25_54,
    "US Population (25-54)": us_population_65,
    #"Cleveland HPI": cle_hpi,
    #"US Population (20-24)": us_population_20_24,
    #"Cle New Listings": cle_new_listings,
    #"US New Listings" : us_new_listings,
    #"OH New Listings" : oh_new_listings,
    #"30-Year Mortgage Rate": mortgage_rate_30yr,
    #"Cle Market Hotness": cle_hotness,
    #"US Debt to Income": debt_to_Income,
    "US Mortgage to Income": mortgage_to_Income,
    #"Deliquency to Income": Delinquency_to_Income,
    "Unemployment": Unemployment,
    #"Cleveland Unemployment": CleUnemployment,
    #"Cleveland Salaries": CleSalaries,
    #"Salaries": Salaries,
    "CPI": CPI,
    #"Credit Card Delinquency": CCDelinq,
    #"Housing Inventory": HousingInventory,
    #"SP500": SP500,
    #"Real GDP" : RGDP
})

#

#Name Dependent Variable Here
predCol = "Ohio HPI"
#Specify Periods out to forcast
forwardCols = 5
#Specify Date Aggregation
DAGG = 'Y'
#Specify Max Rows
pd.set_option('display.max_rows', 60)

# %%
hpi_df.columns.tolist()[1:]
# Out:
# ['USA HPI',
#  'US Population (25-54)',
#  'US Mortgage to Income',
#  'Unemployment',
#  'CPI']

# %%
#Adds a date column and selects the earliest value for each column for each year
dateColName = "Date"
firstCol = "First_Of"
hpi_df.index.name = dateColName  # Set the index name for clarity
hpi_df = hpi_df.reset_index()
hpi_df[firstCol] = hpi_df[dateColName].dt.to_period(DAGG).dt.start_time
hpi_df = hpi_df.groupby(firstCol).first()
hpi_df = hpi_df.reset_index().drop(columns=[firstCol])

#Convert to First Difference:
#firstDifCols = hpi_df.columns.tolist()[1:]

#firstDifCols = ['30-Year Mortgage Rate'] 
#for c in firstDifCols:
#    hpi_df[c] = hpi_df[c].diff() 

#Convert to % change
pctChgCols = ['US Population (25-54)','Ohio HPI','USA HPI',"CPI"] 
for c in pctChgCols:
    hpi_df[c] = hpi_df[c].pct_change(fill_method=None) * 100 

hpi_df.to_csv("Correctly_Specified_Percent_Change_Source.csv")
hpi_df
# Out:
#          Date   Ohio HPI    USA HPI  US Population (25-54)  \
# 0  1947-01-01        NaN        NaN                    NaN
# 1  1948-01-01        NaN        NaN                    NaN
# 2  1949-01-01        NaN        NaN                    NaN
# 3  1950-01-01        NaN        NaN                    NaN
# 4  1951-01-01        NaN        NaN                    NaN
# ..        ...        ...        ...                    ...
# 73 2020-01-01   6.150605   5.086924               2.733060
# 74 2021-01-01   7.782188   7.568986               2.807644
# 75 2022-01-01  16.531528  19.509271               2.693374
# 76 2023-01-01   8.818657   8.070570               2.684468
# 77 2024-01-01   7.844010   6.408348                    NaN
#
#     US Mortgage to Income  Unemployment        CPI
# 0                     NaN           NaN        NaN
# 1                     NaN           3.4  10.242086
# 2                     NaN           4.3   1.393581
# 3                     NaN           6.5  -2.082466
# 4                     NaN           3.7   7.954062
# ..                    ...           ...        ...
# 73               5.915147           3.6   2.512264
# 74               4.784710           6.4   1.395101
# 75               5.667339           4.0   7.569767
# 76               5.691535           3.4   6.362123
# 77               5.903333           3.7   3.105981
#
# [78 rows x 7 columns]

# %%
#Build dataframe for test and train
predCols = []
hpi_df_Source = hpi_df.set_index('Date')
hpi_df_pres = hpi_df_Source[[predCol]]
for c in range(1,forwardCols+1):
    predColNext = "Next "+ predCol + " " + str(c) + " Yr Out"
    hpi_df_Source[predColNext] = hpi_df_Source[predCol].shift(-c)
    predCols.append(predColNext) 
hpi_df_Source = hpi_df_Source.drop(columns = predCol) #Only dropping to account for when we do not have most recent data
testData = hpi_df_Source.drop(columns = predCols).dropna() #To be used for prediction
hpi_df_act = hpi_df_Source.dropna() #To be used to train
hpi_df_act
# Out:
#               USA HPI  US Population (25-54)  US Mortgage to Income  \
# Date
# 1980-01-01   9.397221               0.927112               4.372891
# 1981-01-01   5.190000               0.911998               4.598035
# 1982-01-01   0.903128               0.866369               4.890990
# 1983-01-01   7.810439               0.605022               4.849154
# 1984-01-01   4.369484               0.979308               4.900392
# 1985-01-01   4.580089               1.276249               5.226777
# 1986-01-01   6.261009               0.909342               5.503128
# 1987-01-01   7.338758               0.676194               5.727013
# 1988-01-01   5.004914               1.261129               5.746887
# 1989-01-01   5.220937               1.021723               5.760173
# 1990-01-01   4.980940               0.077689               6.019675
# 1991-01-01   1.476640               0.345402               6.216675
# 1992-01-01   3.065363               0.567365               5.990278
# 2000-01-01           4.0   2.792957
# 2001-01-01           4.2   3.721205
# 2002-01-01           5.7   1.195900
# 2003-01-01           5.8   2.757456
# 2004-01-01           5.7   2.026287
# 2005-01-01           5.3   2.844874
# 2006-01-01           4.7   4.018789
# 2007-01-01           4.6   2.075765
# 2008-01-01           5.0   4.294696
# 2009-01-01           7.8  -0.113586
# 2010-01-01           9.8   2.621111
# 2011-01-01           9.1   1.700783
# 2012-01-01           8.3   3.008766
# 2013-01-01           8.0   1.684062
# 2014-01-01           6.6   1.557759
# 2015-01-01           5.7  -0.229931
# 2016-01-01           4.8   1.237503
# 2017-01-01           4.7   2.510393
# 2018-01-01           4.0   2.151319
# 2019-01-01           4.0   1.487589
# 2020-01-01           3.6   2.512264
# 2021-01-01           6.4   1.395101
# 2022-01-01           4.0   7.569767
# 2023-01-01           3.4   6.362123

# %%
# Standardize the features (VIF can be sensitive to feature scales)
scaler = StandardScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(hpi_df_act), columns=hpi_df_act.columns)
df_scaled = df_scaled.drop(columns = predCols)
# Calculate VIF for each feature
vif_data = pd.DataFrame()
vif_data["feature"] = df_scaled.columns
vif_data["VIF"] = [variance_inflation_factor(df_scaled.values, i) for i in range(df_scaled.shape[1])]

# Display the result
print(vif_data)
# Out:
#                  feature       VIF
# 0                USA HPI  1.915995
# 1  US Population (25-54)  1.127878
# 2  US Mortgage to Income  1.645009
# 3           Unemployment  1.514897
# 4                    CPI  1.260567

# %%
def runRegression(DF,depVar,dropCols):    
    # Separate the independent variables 
    y = DF[depVar]
    X = DF.drop(columns=predCols)
    
    # Add an Intercept (if needed)
    X = sm.add_constant(X)
    
    # Fit the Multiple Regression Model
    model = sm.OLS(y, X).fit()
    
    # Step 1: Print Regression Results
    print(model.summary())
    
    # Step 2: Retrieve model parameters dynamically
    params = model.params.to_dict()  # Convert parameters to a dictionary
    intercept = params.pop('const', 0)  # Extract intercept (default to 0 if 'const' is missing)
    
    # Step 3: Calculate predicted values based on all parameters
    predicted_values = intercept
    for param_name, coefficient in params.items():
        predicted_values += coefficient * DF[param_name]
    
    # Step 4: Plot Actual vs. Predicted
    plt.figure(figsize=(10, 6))
    
    # Scatter plot
    plt.scatter(DF[depVar], predicted_values, color='blue', label='Actual vs. Predicted')
    
    # Add a diagonal line (identity line)
    plt.plot(DF[depVar], DF[depVar], color='red', linestyle='--', label='Identity line')
    
    plt.title(f'Actual vs. Predicted {depVar} (Multiple Regression)')
    plt.xlabel(f'Actual {depVar}')
    plt.ylabel(f'Predicted {depVar}')
    plt.legend()
    plt.grid(True)
    plt.show()
    
    # Step 5: Create a DataFrame for the coefficients
    coefficients = pd.DataFrame({
        'Variable': ['Intercept'] + list(params.keys()),
        'Coefficient': [intercept] + list(params.values())
    }).T
    coefficients.columns = coefficients.iloc[0]  # Set the first row as the header
    coefficients = coefficients.iloc[1:]
    coefficients['Pred_Year'] = depVar
    #print(coefficients)
    return coefficients

#runRegression(hpi_df_pct_chg,'Next Ohio HPI')
coefDf = pd.DataFrame()
for thisCol in predCols:
    coefficients = runRegression(hpi_df_act,thisCol,predCols)
    coefDf = pd.concat([coefDf,coefficients])
coefDf
# Out:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Next Ohio HPI 1 Yr Out   R-squared:                       0.326
# Model:                                OLS   Adj. R-squared:                  0.227
# Method:                     Least Squares   F-statistic:                     3.289
# Date:                    Sun, 24 Nov 2024   Prob (F-statistic):             0.0158
# Time:                            17:25:37   Log-Likelihood:                -106.48
# No. Observations:                      40   AIC:                             225.0
# Df Residuals:                          34   BIC:                             235.1
# Df Model:                               5
# Covariance Type:                nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    21.4287      6.406      3.345      0.002       8.411      34.447
# USA HPI                  -0.0082      0.215     -0.038      0.970      -0.445       0.428
# US Population (25-54)     0.0820      0.718      0.114      0.910      -1.377       1.542
# US Mortgage to Income    -2.2728      0.706     -3.218      0.003      -3.708      -0.837
# Unemployment             -0.4471      0.453     -0.987      0.331      -1.368       0.474
# CPI                      -0.5374      0.250     -2.147      0.039      -1.046      -0.029
# ==============================================================================
# Omnibus:                       25.286   Durbin-Watson:                   2.859
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              188.902
# Skew:                          -0.821   Prob(JB):                     9.56e-42
# Kurtosis:                      13.519   Cond. No.                         112.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Next Ohio HPI 2 Yr Out   R-squared:                       0.386
# Model:                                OLS   Adj. R-squared:                  0.295
# Method:                     Least Squares   F-statistic:                     4.271
# Date:                    Sun, 24 Nov 2024   Prob (F-statistic):            0.00403
# Time:                            17:25:37   Log-Likelihood:                -105.24
# No. Observations:                      40   AIC:                             222.5
# Df Residuals:                          34   BIC:                             232.6
# Df Model:                               5
# Covariance Type:                nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    25.1947      6.210      4.057      0.000      12.574      37.816
# USA HPI                  -0.1780      0.208     -0.855      0.399      -0.601       0.245
# US Population (25-54)     0.5468      0.696      0.785      0.438      -0.868       1.962
# US Mortgage to Income    -2.8895      0.685     -4.219      0.000      -4.281      -1.498
# Unemployment             -0.3162      0.439     -0.720      0.477      -1.209       0.577
# CPI                      -0.6627      0.243     -2.731      0.010      -1.156      -0.169
# ==============================================================================
# Omnibus:                       21.136   Durbin-Watson:                   2.290
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              202.568
# Skew:                          -0.147   Prob(JB):                     1.03e-44
# Kurtosis:                      14.021   Cond. No.                         112.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Next Ohio HPI 3 Yr Out   R-squared:                       0.676
# Model:                                OLS   Adj. R-squared:                  0.628
# Method:                     Least Squares   F-statistic:                     14.17
# Date:                    Sun, 24 Nov 2024   Prob (F-statistic):           1.64e-07
# Time:                            17:25:37   Log-Likelihood:                -88.739
# No. Observations:                      40   AIC:                             189.5
# Df Residuals:                          34   BIC:                             199.6
# Df Model:                               5
# Covariance Type:                nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    25.5341      4.111      6.210      0.000      17.179      33.890
# USA HPI                  -0.1438      0.138     -1.043      0.304      -0.424       0.136
# US Population (25-54)     2.0513      0.461      4.450      0.000       1.115       2.988
# US Mortgage to Income    -3.0786      0.453     -6.791      0.000      -4.000      -2.157
# Unemployment             -0.6608      0.291     -2.272      0.030      -1.252      -0.070
# CPI                       0.0144      0.161      0.090      0.929      -0.312       0.341
# ==============================================================================
# Omnibus:                       10.761   Durbin-Watson:                   1.596
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               12.498
# Skew:                           0.824   Prob(JB):                      0.00193
# Kurtosis:                       5.186   Cond. No.                         112.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Next Ohio HPI 4 Yr Out   R-squared:                       0.679
# Model:                                OLS   Adj. R-squared:                  0.632
# Method:                     Least Squares   F-statistic:                     14.41
# Date:                    Sun, 24 Nov 2024   Prob (F-statistic):           1.36e-07
# Time:                            17:25:38   Log-Likelihood:                -85.063
# No. Observations:                      40   AIC:                             182.1
# Df Residuals:                          34   BIC:                             192.3
# Df Model:                               5
# Covariance Type:                nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    26.3992      3.750      7.039      0.000      18.777      34.021
# USA HPI                  -0.3124      0.126     -2.484      0.018      -0.568      -0.057
# US Population (25-54)     2.1179      0.420      5.037      0.000       1.263       2.972
# US Mortgage to Income    -3.0561      0.414     -7.390      0.000      -3.897      -2.216
# Unemployment             -0.5376      0.265     -2.026      0.051      -1.077       0.002
# CPI                      -0.3741      0.147     -2.553      0.015      -0.672      -0.076
# ==============================================================================
# Omnibus:                       28.172   Durbin-Watson:                   2.006
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               70.114
# Skew:                           1.695   Prob(JB):                     5.96e-16
# Kurtosis:                       8.529   Cond. No.                         112.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Next Ohio HPI 5 Yr Out   R-squared:                       0.661
# Model:                                OLS   Adj. R-squared:                  0.612
# Method:                     Least Squares   F-statistic:                     13.29
# Date:                    Sun, 24 Nov 2024   Prob (F-statistic):           3.31e-07
# Time:                            17:25:38   Log-Likelihood:                -86.798
# No. Observations:                      40   AIC:                             185.6
# Df Residuals:                          34   BIC:                             195.7
# Df Model:                               5
# Covariance Type:                nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    23.9493      3.917      6.115      0.000      15.990      31.909
# USA HPI                  -0.4064      0.131     -3.095      0.004      -0.673      -0.140
# US Population (25-54)     2.4602      0.439      5.603      0.000       1.568       3.353
# US Mortgage to Income    -2.7694      0.432     -6.412      0.000      -3.647      -1.892
# Unemployment             -0.4620      0.277     -1.667      0.105      -1.025       0.101
# CPI                      -0.2524      0.153     -1.650      0.108      -0.563       0.059
# ==============================================================================
# Omnibus:                       12.908   Durbin-Watson:                   1.669
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               15.211
# Skew:                           1.011   Prob(JB):                     0.000498
# Kurtosis:                       5.245   Cond. No.                         112.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Variable     Intercept   USA HPI US Population (25-54) US Mortgage to Income  \
# Coefficient  21.428694 -0.008166              0.082036              -2.27284
# Coefficient  25.194737 -0.178009              0.546787             -2.889463
# Coefficient  25.534105 -0.143755              2.051265             -3.078616
# Coefficient   26.39915 -0.312367              2.117888             -3.056071
# Coefficient  23.949329 -0.406402              2.460216             -2.769379
#
# Variable    Unemployment       CPI               Pred_Year
# Coefficient    -0.447084 -0.537398  Next Ohio HPI 1 Yr Out
# Coefficient    -0.316226 -0.662659  Next Ohio HPI 2 Yr Out
# Coefficient     -0.66079  0.014443  Next Ohio HPI 3 Yr Out
# Coefficient    -0.537633 -0.374094  Next Ohio HPI 4 Yr Out
# Coefficient    -0.461965  -0.25245  Next Ohio HPI 5 Yr Out

# %%
testDataNew = testData.copy()
for ind, row in coefDf.iterrows():
    testDataNew[str(row['Pred_Year'])] = row['Intercept']    
    for i, r in testData.iterrows():
        coefSum = 0
        for c, v in r.items():
            coefSum = row[c] * r[c] + coefSum 
        testDataNew.at[i,str(row['Pred_Year'])] = coefSum + testDataNew.at[i,str(row['Pred_Year'])]

testDataNew = pd.merge(testDataNew, hpi_df_pres, left_index=True, right_index=True, how='left')
testDataNew.to_csv("Correctly_Specified_Percent_Change_Predicted_" + predCol + ".csv")
testDataNew
# Out:
#               USA HPI  US Population (25-54)  US Mortgage to Income  \
# Date
# 1980-01-01   9.397221               0.927112               4.372891
# 1981-01-01   5.190000               0.911998               4.598035
# 1982-01-01   0.903128               0.866369               4.890990
# 1983-01-01   7.810439               0.605022               4.849154
# 1984-01-01   4.369484               0.979308               4.900392
# 1985-01-01   4.580089               1.276249               5.226777
# 1986-01-01   6.261009               0.909342               5.503128
# 1987-01-01   7.338758               0.676194               5.727013
# 1988-01-01   5.004914               1.261129               5.746887
# 1989-01-01   5.220937               1.021723               5.760173
# 1990-01-01   4.980940               0.077689               6.019675
# 1995-01-01                5.610641                5.580499   3.715651
# 1996-01-01                3.728007                3.178896   6.456629
# 1997-01-01                3.925959                3.548393   4.025321
# 1998-01-01                3.936648                2.998465   4.675716
# 1999-01-01                4.146514                3.185242   4.362516
# 2000-01-01                2.921189                1.957020   2.899448
# 2001-01-01                2.514404                1.696596   5.741915
# 2002-01-01                3.057087                2.258510   3.671130
# 2003-01-01                2.103506                1.477510   3.093741
# 2004-01-01                2.860658                2.148941   3.574060
# 2005-01-01               -2.943151               -3.388600   3.715562
# 2006-01-01               -3.979100               -4.132899   1.875071
# 2007-01-01               -2.538599               -2.009413  -0.213236
# 2008-01-01               -1.673951               -0.012411  -1.282147
# 2009-01-01                0.453750                2.129036  -2.016558
# 2010-01-01                0.295365                2.356149  -5.457153
# 2011-01-01                2.950542                4.503478  -2.914771
# 2012-01-01                5.534174                6.991884  -1.165442
# 2013-01-01                5.645648                6.444584  -0.239255
# 2014-01-01                5.036874                5.270976   0.809422
# 2015-01-01                5.922099                5.586627   4.367220
# 2016-01-01                8.321141                8.498750   3.390727
# 2017-01-01                8.709259                9.060971   4.169291
# 2018-01-01                8.079309                8.067560   5.926150
# 2019-01-01                9.814075                9.967472   4.998751
# 2020-01-01                9.646065                9.927331   6.150605
# 2021-01-01               11.395959               11.221244   7.782188
# 2022-01-01                3.707236                3.193147  16.531528
# 2023-01-01                7.961854                8.334990   8.818657

# %%
print("Lastest 5 " + predCol)
print(testDataNew[[predCol]][-5:])
print(predCol + " " + str(forwardCols) +  " year Housing Price Index forcast:")
testDataNew[predCols][-1:]
# Out:
# Lastest 5 Ohio HPI
#              Ohio HPI
# Date
# 2019-01-01   4.998751
# 2020-01-01   6.150605
# 2021-01-01   7.782188
# 2022-01-01  16.531528
# 2023-01-01   8.818657
# Ohio HPI 5 year Housing Price Index forcast:
#             Next Ohio HPI 1 Yr Out  Next Ohio HPI 2 Yr Out  \
# Date
# 2023-01-01                3.707983                3.489366
#
#             Next Ohio HPI 3 Yr Out  Next Ohio HPI 4 Yr Out  \
# Date
# 2023-01-01               10.203629                7.961854
#
#             Next Ohio HPI 5 Yr Out
# Date
# 2023-01-01                 8.33499

# %%
#Check RMSE for each forcast year
print("Evaluating Model Based on Root Mean Squared Errors:")
for c in range(1,forwardCols+1):
    predColNext = "Next "+ predCol + " " + str(c) + " Yr Out"
    RMSE = np.sqrt(((testDataNew[predCol] - testDataNew[predColNext].shift(c)) ** 2).mean())
    RMSERatio = RMSE / testDataNew[predColNext].mean()
    print("RMSE for {} forcast {}, RMSE as a % of column average {}%".format(predColNext,round(RMSE,2),round(RMSERatio*100,2)))
# Out:
# Evaluating Model Based on Root Mean Squared Errors:
# RMSE for Next Ohio HPI 1 Yr Out forcast 3.77, RMSE as a % of column average 120.41%
# RMSE for Next Ohio HPI 2 Yr Out forcast 3.67, RMSE as a % of column average 113.54%
# RMSE for Next Ohio HPI 3 Yr Out forcast 2.2, RMSE as a % of column average 50.11%
# RMSE for Next Ohio HPI 4 Yr Out forcast 2.03, RMSE as a % of column average 49.45%
# RMSE for Next Ohio HPI 5 Yr Out forcast 2.12, RMSE as a % of column average 50.48%
