# %%
import numpy as np
from fredapi import Fred
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm
import matplotlib.pyplot as plt
from datetime import datetime

# Set your FRED API key
fred = Fred(api_key='Enter Your API Key Here')

# %%
# Fetch data for Ohio HPI, USA HPI, Ohio Housing Permits, USA Housing Permits, Ohio Population, USA Population, 30-Year Mortgage Rate, and US Working-Age Population (25-54)
oh_hpi = fred.get_series("OHSTHPI")
us_hpi = fred.get_series("USSTHPI")
oh_permits = fred.get_series("OHBPPRIV")
us_permits = fred.get_series("PERMITNSA")
oh_population = fred.get_series("OHPOP")
us_population = fred.get_series("POPTHM")
mortgage_rate_30yr = fred.get_series("MORTGAGE30US")
us_population_25_54 = fred.get_series("LNU00000060")
us_population_65 = fred.get_series("SPPOP65UPTOZSUSA")
clevel_pop = fred.get_series("CVLPOP")
cle_hpi = fred.get_series("ATNHPIUS39035A")
us_population_20_24 = fred.get_series("LNU00000036")
cle_new_listings = fred.get_series("NEWLISCOU39035")
us_new_listings = fred.get_series("MSACSR")
oh_new_listings = fred.get_series("MSACSR")
cle_hotness = fred.get_series("SUSCCOUNTY39035")
debt_to_Income = fred.get_series("TDSP")
mortgage_to_Income = fred.get_series("MDSP")
Delinquency_to_Income = fred.get_series("DRSFRMACBS")
Unemployment = fred.get_series("UNRATE")
CleUnemployment = fred.get_series("OHCUYA5URN")
CleSalaries = fred.get_series("SMU39174600500000003")
Salaries = fred.get_series("BA06RC1A027NBEA")
CPI = fred.get_series("CPIAUCSL")
CCDelinq = fred.get_series("DRCCLACBS")
HousingInventory = fred.get_series("EYRVACUSQ176N")
SP500 = fred.get_series("SP500")
RGDP = fred.get_series("GDPC1")

# %%
# Combine all series into a single DataFrame, comment out variables you do not need.
hpi_df = pd.DataFrame({
    "Ohio HPI": oh_hpi,
    "USA HPI": us_hpi,
    #"Ohio Housing Permits": oh_permits,
    #"USA Housing Permits": us_permits,
    #"Ohio Population": oh_population,
    #"USA Population": us_population,
    #"Cleveland Population" : clevel_pop,
    #"US Population (Over 65)": us_population_25_54,
    "US Population (25-54)": us_population_65,
    #"Cleveland HPI": cle_hpi,
    #"US Population (20-24)": us_population_20_24,
    #"Cle New Listings": cle_new_listings,
    #"US New Listings" : us_new_listings,
    #"OH New Listings" : oh_new_listings,
    #"30-Year Mortgage Rate": mortgage_rate_30yr,
    #"Cle Market Hotness": cle_hotness,
    #"US Debt to Income": debt_to_Income,
    "US Mortgage to Income": mortgage_to_Income,
    #"Deliquency to Income": Delinquency_to_Income,
    "Unemployment": Unemployment,
    #"Cleveland Unemployment": CleUnemployment,
    #"Cleveland Salaries": CleSalaries,
    #"Salaries": Salaries,
    #"CPI": CPI,
    "Credit Card Delinquency": CCDelinq,
    #"Housing Inventory": HousingInventory,
    #"SP500": SP500,
    #"Real GDP" : RGDP
})

#

#Name Dependent Variable Here
predCol = "Ohio HPI"
#Specify Periods out to forcast
forwardCols = 5
#Specify Date Aggregation
DAGG = 'Y'
#Specify Max Rows
pd.set_option('display.max_rows', 60)

# %%
hpi_df.columns.tolist()[1:]
# Out:
# ['USA HPI',
#  'US Population (25-54)',
#  'US Mortgage to Income',
#  'Unemployment',
#  'Credit Card Delinquency']

# %%
#Adds a date column and selects the earliest value for each column for each year
dateColName = "Date"
firstCol = "First_Of"
hpi_df.index.name = dateColName  # Set the index name for clarity
hpi_df = hpi_df.reset_index()
hpi_df[firstCol] = hpi_df[dateColName].dt.to_period(DAGG).dt.start_time
hpi_df = hpi_df.groupby(firstCol).first()
hpi_df = hpi_df.reset_index().drop(columns=[firstCol])

#Convert to First Difference:
#firstDifCols = hpi_df.columns.tolist()[1:]

#firstDifCols = ['30-Year Mortgage Rate'] 
#for c in firstDifCols:
#    hpi_df[c] = hpi_df[c].diff() 

#Convert to % change
pctChgCols = ['US Population (25-54)'] 
for c in pctChgCols:
    hpi_df[c] = hpi_df[c].pct_change(fill_method=None) * 100 

hpi_df.to_csv("Low_RMSE_Actual_Source.csv")
hpi_df
# Out:
#          Date  Ohio HPI  USA HPI  US Population (25-54)  \
# 0  1948-01-01       NaN      NaN                    NaN
# 1  1949-01-01       NaN      NaN                    NaN
# 2  1950-01-01       NaN      NaN                    NaN
# 3  1951-01-01       NaN      NaN                    NaN
# 4  1952-01-01       NaN      NaN                    NaN
# ..        ...       ...      ...                    ...
# 72 2020-01-01    312.38   449.73               2.733060
# 73 2021-01-01    336.69   483.77               2.807644
# 74 2022-01-01    392.35   578.15               2.693374
# 75 2023-01-01    426.95   624.81               2.684468
# 76 2024-01-01    460.44   664.85                    NaN
#
#     US Mortgage to Income  Unemployment  Credit Card Delinquency
# 0                     NaN           3.4                      NaN
# 1                     NaN           4.3                      NaN
# 2                     NaN           6.5                      NaN
# 3                     NaN           3.7                      NaN
# 4                     NaN           3.2                      NaN
# ..                    ...           ...                      ...
# 72               5.915147           3.6                     2.66
# 73               4.784710           6.4                     1.86
# 74               5.667339           4.0                     1.67
# 75               5.691535           3.4                     2.45
# 76               5.903333           3.7                     3.15
#
# [77 rows x 7 columns]

# %%
#Build dataframe for test and train
predCols = []
hpi_df_Source = hpi_df.set_index('Date')
hpi_df_pres = hpi_df_Source[[predCol]]
for c in range(1,forwardCols+1):
    predColNext = "Next "+ predCol + " " + str(c) + " Yr Out"
    hpi_df_Source[predColNext] = hpi_df_Source[predCol].shift(-c)
    predCols.append(predColNext) 
hpi_df_Source = hpi_df_Source.drop(columns = predCol) #Only dropping to account for when we do not have most recent data
testData = hpi_df_Source.drop(columns = predCols).dropna() #To be used for prediction
hpi_df_act = hpi_df_Source.dropna() #To be used to train
hpi_df_act
# Out:
#             USA HPI  US Population (25-54)  US Mortgage to Income  \
# Date
# 1991-01-01   167.68               0.345402               6.216675
# 1992-01-01   172.82               0.567365               5.990278
# 1993-01-01   175.70               0.246053               5.773480
# 1994-01-01   181.42               0.455690               5.563705
# 1995-01-01   184.05               0.477852               5.648761
# 1996-01-01   193.57               0.053686               5.600129
# 2014-01-01   331.44               1.760034               6.382673
# 2015-01-01   349.34               1.359625               6.116055
# 2016-01-01   366.27               2.404825               6.090748
# 2017-01-01   385.47               2.685186               5.979369
# 2018-01-01   409.15               2.199660               5.924021
# 2019-01-01   427.96               2.559495               5.844992
# 2020-01-01   449.73               2.733060               5.915147
# 2021-01-01   483.77               2.807644               4.784710
# 2022-01-01   578.15               2.693374               5.667339
# 2023-01-01   624.81               2.684468               5.691535
#
#             Unemployment  Credit Card Delinquency
# Date
# 1991-01-01           6.4                     5.26
# 1992-01-01           7.3                     5.27
# 1993-01-01           7.3                     4.60
# 1994-01-01           6.6                     3.60
# 1995-01-01           5.6                     3.48
# 1996-01-01           5.6                     4.04
# 1997-01-01           5.3                     4.70
# 1998-01-01           4.6                     4.76
# 1999-01-01           4.3                     4.66
# 2000-01-01           4.0                     4.43
# 2001-01-01           4.2                     4.81
# 2002-01-01           5.7                     4.94
# 2003-01-01           5.8                     4.68
# 2004-01-01           5.7                     4.21
# 2005-01-01           5.3                     3.70
# 2006-01-01           4.7                     3.86
# 2007-01-01           4.6                     3.98
# 2008-01-01           5.0                     4.77
# 2009-01-01           7.8                     6.51
# 2010-01-01           9.8                     5.78
# 2011-01-01           9.1                     3.82
# 2012-01-01           8.3                     3.06
# 2013-01-01           8.0                     2.64
# 2014-01-01           6.6                     2.32
# 2015-01-01           5.7                     2.11
# 2016-01-01           4.8                     2.14
# 2017-01-01           4.7                     2.39
# 2018-01-01           4.0                     2.48
# 2019-01-01           4.0                     2.51
# 2020-01-01           3.6                     2.66
# 2021-01-01           6.4                     1.86
# 2022-01-01           4.0                     1.67
# 2023-01-01           3.4                     2.45

# %%
# Standardize the features (VIF can be sensitive to feature scales)
scaler = StandardScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(hpi_df_act), columns=hpi_df_act.columns)
df_scaled = df_scaled.drop(columns = predCols)
# Calculate VIF for each feature
vif_data = pd.DataFrame()
vif_data["feature"] = df_scaled.columns
vif_data["VIF"] = [variance_inflation_factor(df_scaled.values, i) for i in range(df_scaled.shape[1])]

# Display the result
print(vif_data)
# Out:
#                    feature       VIF
# 0                  USA HPI  5.757445
# 1    US Population (25-54)  5.255358
# 2    US Mortgage to Income  3.277479
# 3             Unemployment  2.622109
# 4  Credit Card Delinquency  3.187361

# %%
def runRegression(DF,depVar,dropCols):    
    # Separate the independent variables 
    y = DF[depVar]
    X = DF.drop(columns=predCols)
    
    # Add an Intercept (if needed)
    X = sm.add_constant(X)
    
    # Fit the Multiple Regression Model
    model = sm.OLS(y, X).fit()
    
    # Step 1: Print Regression Results
    print(model.summary())
    
    # Step 2: Retrieve model parameters dynamically
    params = model.params.to_dict()  # Convert parameters to a dictionary
    intercept = params.pop('const', 0)  # Extract intercept (default to 0 if 'const' is missing)
    
    # Step 3: Calculate predicted values based on all parameters
    predicted_values = intercept
    for param_name, coefficient in params.items():
        predicted_values += coefficient * DF[param_name]
    
    # Step 4: Plot Actual vs. Predicted
    plt.figure(figsize=(10, 6))
    
    # Scatter plot
    plt.scatter(DF[depVar], predicted_values, color='blue', label='Actual vs. Predicted')
    
    # Add a diagonal line (identity line)
    plt.plot(DF[depVar], DF[depVar], color='red', linestyle='--', label='Identity line')
    
    plt.title(f'Actual vs. Predicted {depVar} (Multiple Regression)')
    plt.xlabel(f'Actual {depVar}')
    plt.ylabel(f'Predicted {depVar}')
    plt.legend()
    plt.grid(True)
    plt.show()
    
    # Step 5: Create a DataFrame for the coefficients
    coefficients = pd.DataFrame({
        'Variable': ['Intercept'] + list(params.keys()),
        'Coefficient': [intercept] + list(params.values())
    }).T
    coefficients.columns = coefficients.iloc[0]  # Set the first row as the header
    coefficients = coefficients.iloc[1:]
    coefficients['Pred_Year'] = depVar
    #print(coefficients)
    return coefficients

#runRegression(hpi_df_pct_chg,'Next Ohio HPI')
coefDf = pd.DataFrame()
for thisCol in predCols:
    coefficients = runRegression(hpi_df_act,thisCol,predCols)
    coefDf = pd.concat([coefDf,coefficients])
coefDf
# Out:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Next Ohio HPI 1 Yr Out   R-squared:                       0.974
# Model:                                OLS   Adj. R-squared:                  0.968
# Method:                     Least Squares   F-statistic:                     172.5
# Date:                    Sun, 24 Nov 2024   Prob (F-statistic):           1.93e-17
# Time:                            17:25:11   Log-Likelihood:                -94.584
# No. Observations:                      29   AIC:                             201.2
# Df Residuals:                          23   BIC:                             209.4
# Df Model:                               5
# Covariance Type:                nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                     116.3260     10.748     10.823      0.000      94.093     138.559
# USA HPI                     0.7052      0.040     17.787      0.000       0.623       0.787
# US Population (25-54)     -14.3659      2.976     -4.827      0.000     -20.523      -8.209
# US Mortgage to Income     -14.0529      2.278     -6.170      0.000     -18.765      -9.341
# Unemployment                1.2302      1.372      0.896      0.379      -1.609       4.069
# Credit Card Delinquency     2.5006      2.063      1.212      0.238      -1.767       6.768
# ==============================================================================
# Omnibus:                        0.623   Durbin-Watson:                   1.431
# Prob(Omnibus):                  0.732   Jarque-Bera (JB):                0.564
# Skew:                          -0.308   Prob(JB):                        0.754
# Kurtosis:                       2.703   Cond. No.                     2.46e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.46e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Next Ohio HPI 2 Yr Out   R-squared:                       0.979
# Model:                                OLS   Adj. R-squared:                  0.974
# Method:                     Least Squares   F-statistic:                     210.3
# Date:                    Sun, 24 Nov 2024   Prob (F-statistic):           2.11e-18
# Time:                            17:25:11   Log-Likelihood:                -92.783
# No. Observations:                      29   AIC:                             197.6
# Df Residuals:                          23   BIC:                             205.8
# Df Model:                               5
# Covariance Type:                nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                     163.3931     10.100     16.177      0.000     142.499     184.287
# USA HPI                     0.7375      0.037     19.796      0.000       0.660       0.815
# US Population (25-54)     -11.7589      2.797     -4.204      0.000     -17.545      -5.973
# US Mortgage to Income     -22.4036      2.140    -10.467      0.000     -26.831     -17.976
# Unemployment                0.9253      1.290      0.717      0.480      -1.743       3.593
# Credit Card Delinquency     3.3312      1.939      1.718      0.099      -0.679       7.342
# ==============================================================================
# Omnibus:                        1.589   Durbin-Watson:                   1.628
# Prob(Omnibus):                  0.452   Jarque-Bera (JB):                0.682
# Skew:                          -0.338   Prob(JB):                        0.711
# Kurtosis:                       3.327   Cond. No.                     2.46e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.46e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Next Ohio HPI 3 Yr Out   R-squared:                       0.964
# Model:                                OLS   Adj. R-squared:                  0.957
# Method:                     Least Squares   F-statistic:                     124.2
# Date:                    Sun, 24 Nov 2024   Prob (F-statistic):           7.44e-16
# Time:                            17:25:11   Log-Likelihood:                -104.16
# No. Observations:                      29   AIC:                             220.3
# Df Residuals:                          23   BIC:                             228.5
# Df Model:                               5
# Covariance Type:                nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                     216.5030     14.953     14.479      0.000     185.570     247.436
# USA HPI                     0.7782      0.055     14.109      0.000       0.664       0.892
# US Population (25-54)      -2.3224      4.141     -0.561      0.580     -10.889       6.244
# US Mortgage to Income     -33.6877      3.169    -10.631      0.000     -40.243     -27.132
# Unemployment               -0.8119      1.909     -0.425      0.675      -4.762       3.138
# Credit Card Delinquency     7.8464      2.870      2.734      0.012       1.909      13.784
# ==============================================================================
# Omnibus:                       12.011   Durbin-Watson:                   1.567
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               12.189
# Skew:                           1.112   Prob(JB):                      0.00226
# Kurtosis:                       5.267   Cond. No.                     2.46e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.46e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Next Ohio HPI 4 Yr Out   R-squared:                       0.956
# Model:                                OLS   Adj. R-squared:                  0.947
# Method:                     Least Squares   F-statistic:                     100.7
# Date:                    Sun, 24 Nov 2024   Prob (F-statistic):           7.40e-15
# Time:                            17:25:11   Log-Likelihood:                -111.65
# No. Observations:                      29   AIC:                             235.3
# Df Residuals:                          23   BIC:                             243.5
# Df Model:                               5
# Covariance Type:                nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                     271.8553     19.358     14.043      0.000     231.810     311.901
# USA HPI                     0.7882      0.071     11.038      0.000       0.640       0.936
# US Population (25-54)      10.4593      5.361      1.951      0.063      -0.631      21.549
# US Mortgage to Income     -43.3721      4.102    -10.572      0.000     -51.859     -34.886
# Unemployment               -3.4502      2.472     -1.396      0.176      -8.563       1.663
# Credit Card Delinquency    12.2650      3.716      3.301      0.003       4.578      19.952
# ==============================================================================
# Omnibus:                        0.734   Durbin-Watson:                   1.488
# Prob(Omnibus):                  0.693   Jarque-Bera (JB):                0.090
# Skew:                          -0.025   Prob(JB):                        0.956
# Kurtosis:                       3.269   Cond. No.                     2.46e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.46e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Next Ohio HPI 5 Yr Out   R-squared:                       0.958
# Model:                                OLS   Adj. R-squared:                  0.948
# Method:                     Least Squares   F-statistic:                     103.7
# Date:                    Sun, 24 Nov 2024   Prob (F-statistic):           5.40e-15
# Time:                            17:25:11   Log-Likelihood:                -115.80
# No. Observations:                      29   AIC:                             243.6
# Df Residuals:                          23   BIC:                             251.8
# Df Model:                               5
# Covariance Type:                nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                     328.6056     22.338     14.711      0.000     282.396     374.815
# USA HPI                     0.7557      0.082      9.171      0.000       0.585       0.926
# US Population (25-54)      27.5243      6.186      4.449      0.000      14.727      40.321
# US Mortgage to Income     -51.0073      4.734    -10.775      0.000     -60.800     -41.215
# Unemployment               -7.0225      2.852     -2.462      0.022     -12.923      -1.122
# Credit Card Delinquency    16.7618      4.288      3.909      0.001       7.892      25.632
# ==============================================================================
# Omnibus:                        2.662   Durbin-Watson:                   1.476
# Prob(Omnibus):                  0.264   Jarque-Bera (JB):                1.438
# Skew:                          -0.497   Prob(JB):                        0.487
# Kurtosis:                       3.451   Cond. No.                     2.46e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.46e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Variable      Intercept   USA HPI US Population (25-54) US Mortgage to Income  \
# Coefficient  116.326038  0.705174            -14.365861            -14.052911
# Coefficient  163.393138  0.737536            -11.758917            -22.403579
# Coefficient  216.502959  0.778247             -2.322386             -33.68775
# Coefficient  271.855304  0.788186             10.459264            -43.372114
# Coefficient  328.605574  0.755678             27.524278            -51.007315
#
# Variable    Unemployment Credit Card Delinquency               Pred_Year
# Coefficient     1.230194                2.500597  Next Ohio HPI 1 Yr Out
# Coefficient     0.925257                3.331189  Next Ohio HPI 2 Yr Out
# Coefficient    -0.811916                7.846384  Next Ohio HPI 3 Yr Out
# Coefficient    -3.450168               12.265032  Next Ohio HPI 4 Yr Out
# Coefficient    -7.022529               16.761752  Next Ohio HPI 5 Yr Out

# %%
testDataNew = testData.copy()
for ind, row in coefDf.iterrows():
    testDataNew[str(row['Pred_Year'])] = row['Intercept']    
    for i, r in testData.iterrows():
        coefSum = 0
        for c, v in r.items():
            coefSum = row[c] * r[c] + coefSum 
        testDataNew.at[i,str(row['Pred_Year'])] = coefSum + testDataNew.at[i,str(row['Pred_Year'])]

testDataNew = pd.merge(testDataNew, hpi_df_pres, left_index=True, right_index=True, how='left')
testDataNew.to_csv("Low_RMSE_Actual_Predicted_" + predCol + ".csv")
testDataNew
# Out:
#             USA HPI  US Population (25-54)  US Mortgage to Income  \
# Date
# 1991-01-01   167.68               0.345402               6.216675
# 1992-01-01   172.82               0.567365               5.990278
# 1993-01-01   175.70               0.246053               5.773480
# 1994-01-01   181.42               0.455690               5.563705
# 1995-01-01   184.05               0.477852               5.648761
# 1996-01-01   193.57               0.053686               5.600129
# 1997-01-01   197.90              -0.289752               5.619890
# 1998-01-01   207.94              -0.419769               5.531760
# 1999-01-01   217.52              -0.524031               5.486907
# 2000-01-01   230.16              -0.633592               5.603787
# 2001-01-01   247.81              -0.167925               5.720924
# 2002-01-01   262.76              -0.077154               5.818683
# 2003-01-01   279.77              -0.077506               5.876676
# 2004-01-01   300.35               0.218155               5.850716
# 2005-01-01   333.76               0.450588               7.495970
# 2006-01-01   368.70               0.500876               7.898613
# 2007-01-01   380.80               0.690157               8.548444
# 2008-01-01   372.32               1.303625               8.911721
# 2009-01-01   350.81               1.463200               8.736014
# 2010-01-01   326.23               1.337247               8.139607
# 2011-01-01   315.09               1.857701               7.500138
# 2012-01-01   310.00               2.367965               6.805059
# 2013-01-01   316.71               2.257280               6.520457
# 2014-01-01   331.44               1.760034               6.382673
# 2015-01-01   349.34               1.359625               6.116055
# 2016-01-01   366.27               2.404825               6.090748
# 2017-01-01   385.47               2.685186               5.979369
# 2018-01-01   409.15               2.199660               5.924021
# 2019-01-01   427.96               2.559495               5.844992
# 2020-01-01   449.73               2.733060               5.915147
# 2021-01-01   483.77               2.807644               4.784710
# 2022-01-01   578.15               2.693374               5.667339
# 2023-01-01   624.81               2.684468               5.691535
#
#             Unemployment  Credit Card Delinquency  Next Ohio HPI 1 Yr Out  \
# Date
# 1991-01-01           6.4                     5.26              163.271688
# 1992-01-01           7.3                     5.27              168.021310
# 1993-01-01           7.3                     4.60              176.039369
# 1994-01-01           6.6                     3.60              176.647576
# 1995-01-01           5.6                     3.48              175.458250
# 1997-01-01              220.420037              225.084300    192.27
# 1998-01-01              233.946946              239.509421    201.26
# 1999-01-01              242.161186              246.597498    210.04
# 2000-01-01              244.122701              245.423515    216.13
# 2001-01-01              261.794924              270.568491    228.54
# 2002-01-01              266.706894              271.023086    236.93
# 2003-01-01              274.061055              275.849093    244.26
# 2004-01-01              289.080717              293.687170    252.99
# 2005-01-01              241.611862              235.672452    262.39
# 2006-01-01              256.246089              249.817614    267.31
# 2007-01-01              241.395158              233.738659    266.74
# 2008-01-01              233.680978              236.118763    263.32
# 2009-01-01              237.697604              242.721057    258.01
# 2010-01-01              227.020225              224.819701    243.93
# 2011-01-01              229.794175              235.406910    236.82
# 2012-01-01              254.705050              273.938369    234.06
# 2013-01-01              267.063617              285.546032    233.50
# 2014-01-01              280.354190              294.486615    235.39
# 2015-01-01              302.368025              313.392059    245.67
# 2016-01-01              331.214756              363.068012    254.00
# 2017-01-01              357.522326              395.867604    264.59
# 2018-01-01              377.027862              409.645774    280.27
# 2019-01-01              399.412858              438.298169    294.28
# 2020-01-01              418.564086              461.271375    312.38
# 2021-01-01              475.730994              513.635601    336.69
# 2022-01-01              516.593404              550.460065    392.35
# 2023-01-01              563.864425              601.528373    426.95

# %%
print("Lastest 5 " + predCol)
print(testDataNew[[predCol]][-5:])
print(predCol + " " + str(forwardCols) +  " year Housing Price Index forcast:")
testDataNew[predCols][-1:]
# Out:
# Lastest 5 Ohio HPI
#             Ohio HPI
# Date
# 2019-01-01    294.28
# 2020-01-01    312.38
# 2021-01-01    336.69
# 2022-01-01    392.35
# 2023-01-01    426.95
# Ohio HPI 5 year Housing Price Index forcast:
#             Next Ohio HPI 1 Yr Out  Next Ohio HPI 2 Yr Out  \
# Date
# 2023-01-01              448.687815              476.443081
#
#             Next Ohio HPI 3 Yr Out  Next Ohio HPI 4 Yr Out  \
# Date
# 2023-01-01              521.253122              563.864425
#
#             Next Ohio HPI 5 Yr Out
# Date
# 2023-01-01              601.528373

# %%
#Check RMSE for each forcast year
print("Evaluating Model Based on Root Mean Squared Errors:")
for c in range(1,forwardCols+1):
    predColNext = "Next "+ predCol + " " + str(c) + " Yr Out"
    RMSE = np.sqrt(((testDataNew[predCol] - testDataNew[predColNext].shift(c)) ** 2).mean())
    RMSERatio = RMSE / testDataNew[predColNext].mean()
    print("RMSE for {} forcast {}, RMSE as a % of column average {}%".format(predColNext,round(RMSE,2),round(RMSERatio*100,2)))
# Out:
# Evaluating Model Based on Root Mean Squared Errors:
# RMSE for Next Ohio HPI 1 Yr Out forcast 8.68, RMSE as a % of column average 3.44%
# RMSE for Next Ohio HPI 2 Yr Out forcast 12.32, RMSE as a % of column average 4.72%
# RMSE for Next Ohio HPI 3 Yr Out forcast 12.32, RMSE as a % of column average 4.51%
# RMSE for Next Ohio HPI 4 Yr Out forcast 11.37, RMSE as a % of column average 3.98%
# RMSE for Next Ohio HPI 5 Yr Out forcast 12.68, RMSE as a % of column average 4.24%
